# %%
US_Accidents_March23

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('US_Accidents_March23.csv')

# Display the first few rows
print(df.head())

# Summary of dataset
print(df.info())

# Check for missing values
print(df.isnull().sum())
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.countplot(x='Weather_Condition', data=df, order=df['Weather_Condition'].value_counts().iloc[:10].index, palette='viridis')
plt.xticks(rotation=45)
plt.title('Top 10 Weather Conditions During Accidents')
plt.xlabel('Weather Condition')
plt.ylabel('Accident Count')
plt.show()
# Out:
# C:\Users\sudip\AppData\Local\Temp\ipykernel_10896\4127320056.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Weather_Condition', data=df, order=df['Weather_Condition'].value_counts().iloc[:10].index, palette='viridis')

# %%
# Convert Start_Time to datetime, handling errors
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')

# Drop rows where conversion failed
df = df.dropna(subset=['Start_Time'])

# Extract hour
df['Hour'] = df['Start_Time'].dt.hour

# Visualize Accidents by Hour
plt.figure(figsize=(10, 6))
sns.countplot(x='Hour', data=df, palette='coolwarm')
plt.title('Accidents by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Accident Count')
plt.show()
# Out:
# C:\Users\sudip\AppData\Local\Temp\ipykernel_10896\3499271579.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Hour', data=df, palette='coolwarm')
